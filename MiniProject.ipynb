# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("StressLevelDataset.csv")

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df.tail()
# Out:
#       anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 1095             11           17                      0          14         3
# 1096              9           12                      0           8         0
# 1097              4           26                      0           3         1
# 1098             21            0                      1          19         5
# 1099             18            6                      1          15         3
#
#       blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 1095               1              3                  2            2
# 1096               3              0                  0            0
# 1097               2              5                  2            2
# 1098               3              1                  4            3
# 1099               3              0                  3            3
#
#       living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
df.columns
# Out:
# Index(['anxiety_level', 'self_esteem', 'mental_health_history', 'depression',
#        'headache', 'blood_pressure', 'sleep_quality', 'breathing_problem',
#        'noise_level', 'living_conditions', 'safety', 'basic_needs',
#        'academic_performance', 'study_load', 'teacher_student_relationship',
#        'future_career_concerns', 'social_support', 'peer_pressure',
#        'extracurricular_activities', 'bullying', 'stress_level'],
#       dtype='object')

# %%
df.describe()
# Out:
#        anxiety_level  self_esteem  mental_health_history   depression  \
# count    1100.000000  1100.000000            1100.000000  1100.000000
# mean       11.063636    17.777273               0.492727    12.555455
# std         6.117558     8.944599               0.500175     7.727008
# min         0.000000     0.000000               0.000000     0.000000
# 25%         6.000000    11.000000               0.000000     6.000000
# 50%        11.000000    19.000000               0.000000    12.000000
# 75%        16.000000    26.000000               1.000000    19.000000
# max        21.000000    30.000000               1.000000    27.000000
#
#           headache  blood_pressure  sleep_quality  breathing_problem  \
# count  1100.000000     1100.000000    1100.000000        1100.000000
# mean      2.508182        2.181818       2.660000           2.753636
# std       1.409356        0.833575       1.548383           1.400713
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(data=df[['anxiety_level', 'self_esteem', 'depression']])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# ## Stres level dependecies on the some features which are AnxietyLevel=74% , Selfesteme=-76% means it is an inverse relation, Depression = 76% dependent, Sleepquality=75% which is an inverse relation, Futurecareerconncerns=74%, Bullying=75%

# %% [markdown]
# ## DepressionDependencies Strongrelation(StressLevel=73%,FutureCareerConcerns=71%, Selfesteme=-70%) WeakRelation(BloodPressure=44%) Rest other are Moderate Relation

# %% [markdown]
# ## AnxietyLevel Dependencied Strongrelation(StressLevel=74%, Bullying=71%, FutureCareerConcerns=72%, SleepQuality=71%), WeakRelation(BloodPressure=33%)

# %% [markdown]
# ## BloodPressure is an unncessary feature

# %%
fig, ax = plt.subplots(figsize=(6, 4))
sns.barplot(x='depression', y='future_career_concerns', data=df, ax=ax)

# Display the plot
plt.show()

# %%
feature_value_stress_counts = df['stress_level'].value_counts()

# %%
ax=feature_value_stress_counts.plot(kind='bar', color='skyblue')

for i in ax.containers:
    ax.bar_label(i)
    
plt.xlabel('Unique Values')
plt.ylabel('Count')
plt.title('Count of Different Values in feature1')

# Show the plot
plt.show()

# %% [markdown]
# ### sns.pairplot(df[['anxiety_level','depression','self_esteem']])
# plt.show()

# %%
# !pip install pydantic==1.10.12
# Out:
# ...
#   Using cached pydantic-1.10.12-py3-none-any.whl.metadata (149 kB)
# ...
# Using cached pydantic-1.10.12-py3-none-any.whl (158 kB)
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.9.2
#     Uninstalling pydantic-2.9.2:
#       Successfully uninstalled pydantic-2.9.2
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.
# pydantic-settings 2.5.2 requires pydantic>=2.7.0, but you have pydantic 1.10.12 which is incompatible.
# ydata-profiling 4.10.0 requires pydantic>=2, but you have pydantic 1.10.12 which is incompatible.

# %%
# !pip install pydantic-settings
# Out:
# ...
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# ...
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# ...
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.12
#     Uninstalling pydantic-1.10.12:
#       Successfully uninstalled pydantic-1.10.12
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.

# %%
# !pip install ydata-profiling

# %%
# !pip install setuptools

# %%
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
X = df.drop(columns=['stress_level']) 
y = df['stress_level']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42)

# %%
model_1 = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=200)

# %%
model_1.fit(X_train, y_train)
# Out:
# C:\Users\dines\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\dines\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=200, multi_class='multinomial')

# %%
y_pred = model_1.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8982

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89        95
#            1       0.88      0.89      0.89        92
#            2       0.90      0.93      0.92        88
#
#     accuracy                           0.90       275
#    macro avg       0.90      0.90      0.90       275
# weighted avg       0.90      0.90      0.90       275

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
model_2 = LinearDiscriminantAnalysis()

# %%
X = df.drop(columns=['stress_level']) 
y = df['stress_level']

# %%
model_2.fit(X_train, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
y_pred = model_2.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.8982

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
feature_names=['anxiety_level','self_esteem','mental_health_history','depression','headache','blood_pressure','sleep_quality','breathing_problem','noise_level','living_conditions','safety'
,'basic_needs','academic_performance','study_load','teacher_student_relationship','future_career_concerns','social_support','peer_pressure','extracurricular_activities','bullying']

# %%
# Feature names as in the training data
feature_names=['anxiety_level','self_esteem','mental_health_history','depression','headache','blood_pressure','sleep_quality','breathing_problem','noise_level','living_conditions','safety'
,'basic_needs','academic_performance','study_load','teacher_student_relationship','future_career_concerns','social_support','peer_pressure','extracurricular_activities','bullying']

# Function to take user input for each feature
def get_user_input():
    user_data = []
    for feature in feature_names:
        value = input(f"Enter value for {feature}: ")  # Capture input from the user
        user_data.append(float(value))  # Convert to float (or int if necessary)
    return np.array([user_data])

# Take user input for prediction
new_input = get_user_input()

# Convert to DataFrame with proper feature names
new_input_df = pd.DataFrame(new_input, columns=feature_names)

# Predict using the trained model (assuming the model is already trained)
predicted_class = model_1.predict(new_input_df)

print(f"Predicted Class: {predicted_class[0]}")
